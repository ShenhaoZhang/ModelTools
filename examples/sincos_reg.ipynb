# %%
import sys 
sys.path.append('..')

import numpy as np

from ModelTools.regression.linear_model import LinearModel

# %%
rng = np.random.default_rng(0)
x1  = rng.uniform(-np.pi,np.pi,1000)
x2  = rng.uniform(-np.pi,np.pi,1000)
y   = rng.normal(loc=np.sin(x1)+np.cos(x2)+x1*x2+2,scale=2)

mod = LinearModel('y~bs(x1,df=5)+bs(x2,df=5)+I(x1*x2)',data={'y':y,'x1':x1,'x2':x2}).fit(method='OLS')
mod.summary()
# Out:
#                    estimate    std_Error          z    p_value    ci_lower    ci_upper
# ---------------  ----------  -----------  ---------  ---------  ----------  ----------
# Intercept         1.15257      0.456101    2.527         0.016    0.274035    2.0395
# bs(x1, df=5)[0]  -1.15447      0.667985   -1.72829       0.086   -2.49688     0.131021
# bs(x1, df=5)[1]  -2.5198       0.428409   -5.88177       0       -3.30185    -1.67659
# bs(x1, df=5)[2]   1.93981      0.573969    3.37965       0        0.76651     3.10448
# bs(x1, df=5)[3]  -0.431447     0.470122   -0.917734      0.348   -1.37893     0.456679
# bs(x1, df=5)[4]  -0.151461     0.524106   -0.28899       0.77    -1.18275     0.814437
# bs(x2, df=5)[0]  -0.0829147    0.594756   -0.13941       0.87    -1.30575     1.03376
# bs(x2, df=5)[1]   2.07044      0.428656    4.83008       0        1.22792     2.91371
# bs(x2, df=5)[2]   2.73487      0.589993    4.63543       0        1.63738     3.93624
# bs(x2, df=5)[3]  -0.175737     0.473381   -0.371238      0.69    -1.11154     0.762819
# bs(x2, df=5)[4]   0.336646     0.486715    0.69167       0.508   -0.644466    1.27442
# I(x1 * x2)        1.00294      0.0185878  53.9571        0        0.965702    1.03762
#                   R2        MSE         MAE           MBE       MdAE      MAPE      MaxE         SAE      SAPE
# ---------  ---------  ---------  ----------  ------------  ---------  --------  --------  ----------  --------
# estimate   0.76048    3.79029    1.57476     -1.01608e-15  1.29894    2.48458   6.11567   1.14473     21.4934
# std_error  0.0011793  0.0186618  0.00610421   0.0631244    0.0171965  0.109342  0.174643  0.00732317   1.75245
# ci_lower   0.754989   3.80617    1.57321     -0.125258     1.29496    2.28532   5.81026   1.14049     18.4262
# ci_upper   0.759476   3.87718    1.59709      0.131312     1.36343    2.70986   6.47583   1.16873     25.1944

# %%
mod.plot_check()

# %%
mod.plot_coef_dist()
# Out:
# <Figure Size: (640 x 480)>

# %%
mod.plot_prediction({'x1':'line','x2':[-1,0,1]},ci_type='mean')
# Out:
# <Figure Size: (640 x 480)>
